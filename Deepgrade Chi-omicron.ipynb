# %%
import math
import matplotlib.pyplot as plt
import numpy

length = 10
x_coords = [0]*length
for i in range(length):
    x_coords[i] = i+1

y_coords = [0]*length
for i, x in enumerate(x_coords):
    y_coords[i] = 1 - math.log10(x)
    print(x, y_coords[i])
    
plt.figure("Chi", [8,8])
plt.xlabel("p")
plt.ylabel("G(p)")
plt.title(": G(p)")
plt.scatter(x_coords, y_coords)

plt.show()
# Out:
# 1 1.0
# 2 0.6989700043360187
# 3 0.5228787452803376
# 4 0.3979400086720376
# 5 0.30102999566398114
# 6 0.22184874961635637
# 7 0.1549019599857432
# 8 0.09691001300805646
# 9 0.04575749056067513
# 10 0.0
